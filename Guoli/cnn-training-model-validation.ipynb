# %%
from __future__ import print_function
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.optimizers import SGD,RMSprop
from keras.callbacks import *
from keras.utils import np_utils
from keras import backend as K
from sklearn.metrics import classification_report,confusion_matrix
K.set_image_dim_ordering('tf')
# Out:
# Using TensorFlow backend.

# %%
import os,sys
sys.path.append('/home/cs341seti/cs341-ibm-seti/')
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import tensorflow as tf
import keras
import numpy as np
from PIL import Image
import re
import collections
import sklearn
import commonutils as cu
import model_specs
from sklearn import svm
from sklearn.externals import joblib

# %% [markdown]
# ## Exploring data augmentation

# %%
# Might want to tune these parameters
train_datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,
                                   rotation_range=0, width_shift_range=0.2,
                                   height_shift_range=0.1,zoom_range=0.1,
                                   horizontal_flip=True, vertical_flip = True, fill_mode='constant')
test_datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True)

# %%
sampleimg = load_img('../data/imagesDataset_512x256_8/train/3-narrowbanddrd/000050.jpg',grayscale=True)# PIL image
xsample = img_to_array(sampleimg)  # this is a Numpy array with shape (3, 512, 256)
xsample = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 512, 256)
plt.set_cmap('gray')
plt.imshow(sampleimg)
plt.show()

# %%
# # Create a sample dataset array for fitting whitening / normalization parameters
# #(linux command for putting all images in one place) 
# # find train -name '*.jpg' -type f -exec cp {} . \;
trainImgDir = '../data/imagesDataset_512x256_8/train_one_folder/'
files = [f for f in os.listdir(trainImgDir) if f.endswith('.jpg')]
size = img_to_array(load_img(os.path.join(trainImgDir,files[0]),grayscale=True)).shape
trainDataArray = np.zeros((len(files)//5,)+size) # Only 1/10 the data, because memory constraints
for i in range(len(files)//5):
    trainDataArray[i] = img_to_array(load_img(os.path.join(trainImgDir,files[i]),grayscale=True))

# %%
# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
train_datagen.fit(trainDataArray)
test_datagen.fit(trainDataArray)
i = 0
for batch in test_datagen.flow(x, batch_size=1,
                          save_to_dir='previewtest', save_prefix='signaltest', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c102cdb53e7b> in <module>()
#       4 test_datagen.fit(trainDataArray)
#       5 i = 0
# ----> 6 for batch in test_datagen.flow(x, batch_size=1,
#       7                           save_to_dir='previewtest', save_prefix='signaltest', save_format='jpeg'):
#       8     i += 1
#
# NameError: name 'x' is not defined

# %%
# No way we can run PCA on these size images on a single machine. Would need 128Gb memory
flat_x.shape[1]**2*8/(1024**3)
# Out:
# 128

# %%
# Matrix size that'll take up 1GB
np.sqrt((1024**3)/8)
# Out:
# 11585.237502960395

# %% [markdown]
# ## Picking an image from the generator

# %%
# Might want to tune these parameters
train_datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,
                                   rotation_range=0, width_shift_range=0.2,
                                   height_shift_range=0.1,zoom_range=0.1,
                                   horizontal_flip=True, vertical_flip = True, fill_mode='constant')
test_datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True)

# # Create a sample dataset array for fitting whitening / normalization parameters
# #(linux command for putting all images in one place) 
# # find train -name '*.jpg' -type f -exec cp {} . \;
trainImgDir = '../data/imagesDataset_512x256_8/train_one_folder/'
files = [f for f in os.listdir(trainImgDir) if f.endswith('.jpg')]
size = img_to_array(load_img(os.path.join(trainImgDir,files[0]),grayscale=True)).shape
trainDataArray = np.zeros((len(files)//5,)+size) # Only 1/10 the data, because memory constraints
for i in range(len(files)//5):
    trainDataArray[i] = img_to_array(load_img(os.path.join(trainImgDir,files[i]),grayscale=True))
    
train_datagen.fit(trainDataArray)
test_datagen.fit(trainDataArray)

datasetPath = "../data/imagesDataset_512x256_8/train/"
valDataPath = "../data/imagesDataset_512x256_8/validation/"
classList = ['0-noise','2-narrowband','3-narrowbanddrd','5-squiggle']
batch_size = 8
train_generator = train_datagen.flow_from_directory(directory=datasetPath,batch_size=batch_size,class_mode='categorical',
                            classes=classList,target_size=(256,512),color_mode='grayscale')
validation_generator = test_datagen.flow_from_directory(directory=valDataPath,batch_size=batch_size,
        class_mode='categorical',classes=classList,target_size=(256,512),color_mode='grayscale')
# Out:
# Found 7584 images belonging to 4 classes.
# Found 1498 images belonging to 4 classes.

# %%
a = validation_generator.next()

# %%
x = np.expand_dims(a[0][1],axis=0)
# Show the image from the validation generator
plt.imshow(x[0,:,:,0])
plt.set_cmap('gray')
plt.show()

# %% [markdown]
# ## Examining trained model

# %%
modelPath = '../savedModels/cnnModels-2class-aug-fullsearch/setiNetv2_256x512_2class_adamaugment2dropout0.47lr2.76e-04anneal0.11.hdf5'
#model = keras.models.load_model(modelPath)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 512, 8)       80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 512, 8)       32
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 512, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 512, 8)       584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 512, 8)       32
# _________________________________________________________________
# activation_2 (Activation)    (None, 256, 512, 8)       0
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 128, 8)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 128, 16)       1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 128, 16)       64
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 128, 16)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 128, 16)       2320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 128, 16)       64
# _________________________________________________________________
# activation_4 (Activation)    (None, 64, 128, 16)       0
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 64, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 64, 32)        4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 64, 32)        128
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 64, 32)        9248
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 64, 32)        128
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 64, 32)        0
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 32, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 32, 64)        256
# _________________________________________________________________
# activation_7 (Activation)    (None, 16, 32, 64)        0
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 16, 64)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 16, 64)         36928
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 16, 64)         256
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 16, 64)         0
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 128)         131200
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1, 1, 128)         512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# block6_activation (Activatio (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                1040
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16)                64
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 215,786
# Trainable params: 214,890
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Check activations for the image
act = cu.datautils.modelActivations(model=model,layer_name='block6_activation',input=x,show=True)

# %%
# utility functions
from mpl_toolkits.axes_grid1 import make_axes_locatable

def nice_imshow(ax, data, vmin=None, vmax=None, cmap=None):
    """Wrapper around pl.imshow"""
    if cmap is None:
        cmap = cm.jet
    if vmin is None:
        vmin = data.min()
    if vmax is None:
        vmax = data.max()
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    im = ax.imshow(data, vmin=vmin, vmax=vmax, interpolation='nearest', cmap=cmap)
    plt.colorbar(im, cax=cax)

import numpy.ma as ma
def make_mosaic(imgs, nrows, ncols, border=1):
    """
    Given a set of images with all the same shape, makes a
    mosaic with nrows and ncols
    """
    nimgs = imgs.shape[2]
    imshape = imgs.shape[0:2]
    
    mosaic = ma.masked_all((nrows * imshape[0] + (nrows - 1) * border,
                            ncols * imshape[1] + (ncols - 1) * border),
                            dtype=np.float32)
    
    paddedh = imshape[0] + border
    paddedw = imshape[1] + border
    for i in xrange(nimgs):
        row = int(np.floor(i / ncols))
        col = i % ncols
        
        mosaic[row * paddedh:row * paddedh + imshape[0],
               col * paddedw:col * paddedw + imshape[1]] = imgs[:,:,i]
    return mosaic

#pl.imshow(make_mosaic(np.random.random((9, 10, 10)), 3, 3, border=1))

# %%
# Visualize weights
W = model.get_layer(name='conv2d_2').get_weights()[0]
nfilt = W.shape[2]*W.shape[3]
W = np.reshape(W,W.shape[0:2]+(nfilt,))
print("W shape : ", W.shape)

plt.figure(figsize=(10,20))
plt.title('conv1 weights')
nice_imshow(plt.gca(), make_mosaic(W, 8, 8), cmap=cm.binary)
plt.show()
# Out:
# W shape :  (3, 3, 64)

# %%
# Weights distribution of trained network 
layerNames = ['conv2d_1','conv2d_2','conv2d_3','conv2d_4','conv2d_5',
              'conv2d_6','conv2d_7','dense_1','dense_2']
fig = plt.figure(figsize=(10,10))
fig.suptitle('Weights distribution of trained network by layer')
for i in range(len(layerNames)):
    pltIndex = int('33{}'.format(i+1))
    plt.subplot(pltIndex)
    plt.xlim(-1,1)
    W = model.get_layer(name=layerNames[i]).get_weights()[0]
    plt.hist(W.flatten(),bins=20)
plt.show()

# %%
# Activations distribution of trained network 
layerNames = ['activation_1','activation_2','activation_3','activation_4',
              'activation_5','activation_6','activation_7','dense_1','dense_2']
fig = plt.figure(figsize=(10,10))
fig.suptitle('Activations distribution of trained network by layer')
for i in range(len(layerNames)):
    pltIndex = int('33{}'.format(i+1))
    plt.subplot(pltIndex)
    plt.xlim((0,5))
    act = cu.datautils.modelActivations(model=model,layer_name=layerNames[i],input=x,show=False)
    plt.hist(act.flatten(),bins=20)
plt.show()
# Out:
# /home/cs341seti/cs341-ibm-seti/commonutils/datautils.py:48: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("co...)`
#   model_selection = Model(input=model.input, output=model.get_layer(layer_name).output)

# %% [markdown]
# ## Examine activation distributions at initialization

# %%
initialized_model = model_specs.setiNet.build((256,512,1),2,init='he_uniform')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 512, 8)       80
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 512, 8)       32
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 512, 8)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 256, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 256, 8)       584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 256, 8)       32
# _________________________________________________________________
# activation_2 (Activation)    (None, 128, 256, 8)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 128, 8)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 128, 32)       2336
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 128, 32)       128
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 128, 32)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 64, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 64, 32)        9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 64, 32)        128
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 32, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 32, 64)        256
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 16, 64)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 16, 64)         36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 16, 64)         256
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 16, 64)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 8, 128)         512
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 8, 128)         0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 406,810
# Trainable params: 405,626
# Non-trainable params: 1,184
# _________________________________________________________________
# None

# %%
a = initialized_model.get_layer(index=0)

# %%
# Weights distribution of initialized network 
layerNames = ['conv2d_1','conv2d_2','conv2d_3','conv2d_4','conv2d_5',
              'conv2d_6','conv2d_7','dense_1','dense_2']
fig = plt.figure(figsize=(10,10))
fig.suptitle('Weights distribution of initialized network by layer')
for i in range(len(layerNames)):
    pltIndex = int('33{}'.format(i+1))
    plt.subplot(pltIndex)
    plt.xlim((-1,1))
    W = initialized_model.get_layer(name=layerNames[i]).get_weights()[0]
    plt.hist(W.flatten(),bins=20)
plt.show()

# %%
# Activations distribution of initialized network 
layerNames = ['activation_1','activation_2','activation_3','activation_4',
              'activation_5','activation_6','activation_7','dense_1','dense_2']
fig = plt.figure(figsize=(10,10))
fig.suptitle('Activations distribution of initialized network by layer')
for i in range(len(layerNames)):
    pltIndex = int('33{}'.format(i+1))
    plt.subplot(pltIndex)
    plt.xlim((-0.1,10))
    act = cu.datautils.modelActivations(model=initialized_model,layer_name=layerNames[i],input=x,show=False)
    plt.hist(act.flatten(),bins=20)
plt.show()

# %%
act = cu.datautils.modelActivations(model=model,layer_name='dense_2',input=x,show=False)

# %%
plt.hist(act.flatten())
plt.show()

# %%
# Out:
# array([[ 0.02345068,  0.40760127,  0.52628797,  0.04266005]], dtype=float32)

# %% [markdown]
# ## Evaluating models

# %%
subsetClasses = {0.0:0.0,2.0:1.0,3.0:1.0,5.0:1.0}
dataset = cu.datautils.loadDataset("../data/imagesDataset_512x256_8/imagesDataset_512x256_8.h5",
                                   subsetClasses=subsetClasses)

# %%
np.random.uniform(0,5)
# Out:
# 3.419423881986186

# %%
## Checking a saved CNN model
mode = "val"
if mode not in ['test','val']: raise ValueError("mode must be 'train/val'")
keras.backend.get_session().run(tf.global_variables_initializer())
best_model = keras.models.load_model(modelPath)
print("Loaded in model..")
model_prediction = np.argmax(best_model.predict(dataset["x_{}".format(mode)]), axis=1 )
print("\nPrinting results on %s dataset for best saved model: \n" % mode)
y_true = dataset["y_{}".format(mode)]
temp = classification_report(y_true,model_prediction)
print(temp)
temp = confusion_matrix(y_true,model_prediction)
print(temp)
print("Test accuracy: %0.2f " % sklearn.metrics.accuracy_score(
    y_true,model_prediction))
#testPred = cu.modelutils.evaluateSavedModel(modelPath,dataset,mode='test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f6b4ae1e763f> in <module>()
#       3 if mode not in ['test','val']: raise ValueError("mode must be 'train/val'")
#       4 keras.backend.get_session().run(tf.global_variables_initializer())
# ----> 5 best_model = keras.models.load_model(modelPath)
#       6 print("Loaded in model..")
#       7 model_prediction = np.argmax(best_model.predict(dataset["x_{}".format(mode)]), axis=1 )
#
# /home/cs341seti/anaconda3/envs/cs341seti/lib/python2.7/site-packages/keras/models.pyc in load_model(filepath, custom_objects)
#     278         optimizer_weight_names = [n.decode('utf8') for n in optimizer_weights_group.attrs['weight_names']]
#     279         optimizer_weight_values = [optimizer_weights_group[n] for n in optimizer_weight_names]
# --> 280         model.optimizer.set_weights(optimizer_weight_values)
#     281     f.close()
#     282     return model
#
# /home/cs341seti/anaconda3/envs/cs341seti/lib/python2.7/site-packages/keras/optimizers.pyc in set_weights(self, weights)
#      77                                  str(pv.shape) +
#      78                                  ' not compatible with '
# ---> 79                                  'provided weight shape ' + str(w.shape))
#      80             weight_value_tuples.append((p, w))
#      81         K.batch_set_value(weight_value_tuples)
#
# ValueError: Optimizer weight shape (64,) not compatible with provided weight shape (8,)

# %%
## Using the datagen
validation_generator.classes[0:8]
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
model.evaluate_generator(validation_generator,steps=validation_generator.n//validation_generator.batch_size)
# Out:
# [1.453394632691505, 0.42953020134228187]
