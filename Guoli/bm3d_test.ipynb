# %%
import os,sys
import numpy as np
import pandas as pd
import ibmseti
import collections
import scipy.io
import matplotlib.pyplot as plt
import commonutils as cu
import PIL
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
import keras
from keras import backend as K
K.set_image_dim_ordering('tf')
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.models import Model

# %%
# Loading in table with info on files
fileListDF = pd.read_csv("fileList.csv")
# Loading in an arbitrary file
imgPath = "data/specdataimages/"
fnum = 40
imgfiles = [f for f in os.listdir(imgPath) if os.path.isfile(os.path.join(imgPath, f))]
image = np.asarray(Image.open(os.path.join(imgPath,imgfiles[fnum])))
print imgfiles[fnum]
print fileListDF.ix[int(imgfiles[fnum].split(".")[0])]
# Out:
# 000271.jpg
# file_name                03f55ef8-c401-48c5-ac69-db2bdcebe6c3.dat
# signal_classification                               narrowbanddrd
# uuid                         03f55ef8-c401-48c5-ac69-db2bdcebe6c3
# file_index                                                    271
# label                                                           3
# Name: 271, dtype: object

# %%
image = image.astype('float32')
image = np.expand_dims(image,axis=0)
image = preprocess_input(image)
print plt.get_cmap().name
plt.imshow(image[0])
plt.show()
# Out:
# viridis

# %%
from BM3D.BM3D import bm3d_full_step

# %%
imgPath = "sampleImages_small_size/squiggle_5.jpg"
bm3d_full_step(imgPath)
# Out:
# The Processing time of the First step is 64.472621 s
# The PSNR between the two img of the First step is 25.554018
# The Processing time of the Second step is 124.425518 s
# The PSNR between the two img of the Second step is 26.457630
# The total Processing time is 188.898139 s

# %%
# Out:
# <function BM3D.BM3D.bm3d_full_step>
